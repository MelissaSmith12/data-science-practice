# %%
#Read in account information. 

import csv

with open('ab credentials.txt', 'rb') as f:
    reader = csv.reader(f)
    partner_id = next(reader)[0]
    partner_key = next(reader)[0]

# %%
import time
import hashlib
import hmac
import base64
import urllib

#partner_id = 'public'                      # ID provided by AB. 
#partner_key = '2jfaWErgt2+o48gsk302kd'     # Key provided by AB.
expires = str(int(time.time() + 86400))    # Seconds since epoch. Example expires in 24 hours.
user_id = '383485'                         # Partner defined. May be an empty string.

message = expires + "\n" + user_id
digest = hmac.new(partner_key.encode(), message.encode(), digestmod=hashlib.sha256).digest()
signature = base64.b64encode(digest).decode()
encoded_sig = urllib.quote_plus(signature)
parms = 'partner.id=' + partner_id + \
        '&auth.signature=' + encoded_sig + \
        '&auth.expires=' + expires + \
        '&user.id=' + user_id
result = urllib.urlopen('http://api.academicbenchmarks.com/rest/v4/standards?' + parms).read()
print result
# Out:
# {"links":{"self":"http://api.academicbenchmarks.com/rest/v4/standards?user.id=383485","next":"http://api.academicbenchmarks.com/rest/v4/standards?user.id=383485&offset=10","last":"http://api.academicbenchmarks.com/rest/v4/standards?user.id=383485&offset=299270"},"data":[{"type":"standards","relationships":{"parent":{"data":{}}},"id":"286920E2-74F7-11DF-80DD-6B359DFF4B22","attributes":{"education_levels":{"grades":[{"descr":"5th Grade","guid":"F1FA3C84-3B53-11E0-B042-495E9DFF4B22","seq":70,"code":"5"}]},"number":{"raw":"","enhanced":"CCSS.ELA-Literacy.R.5"},"guid":"286920E2-74F7-11DF-80DD-6B359DFF4B22","utilizations":[],"section":{"descr":"Grade 5","guid":"5E1166C2-7377-11DF-A1E8-223D9DFF4B22","seq":920},"label":"Strand","statement":{"addendums":[],"descr":"Reading"},"seq":1,"disciplines":{"subjects":[{"descr":"Language Arts","guid":"F1FAC302-3B53-11E0-B042-495E9DFF4B22","code":"LANG"}],"strands":[{"descr":"Reading","guid":"81C38420-046C-11E0-9AE1-661C9DFF4B22"}]},"document":{"publication":{"guid":"964E0FEE-AD71-11DE-9BF2-C9169DFF4B22","descr":"Common Core State Standards","acronym":"","authorities":[{"guid":"A83297F2-901A-11DF-A622-0C319DFF4B22","descr":"NGA Center/CCSSO","acronym":"CC"}],"regions":[{"code":"US","type":"country","guid":"91273AE8-F1B9-11E5-862E-0938DC287387","descr":"United States of America"},{"code":"CC","type":"other","guid":"A83297F2-901A-11DF-A622-0C319DFF4B22","descr":"CCSS"}]},"adopt_year":"2010","descr":"English Language Arts/Literacy","guid":"CF6A375C-67AD-11DF-AB5F-995D9DFF4B22"},"status":"active","level":1}},{"id":"7F721838-7440-11DF-93FA-01FD9CFF4B22","attributes":{"level":2,"status":"active","document":{"adopt_year":"2010","descr":"English Language Arts/Literacy","guid":"CF6A375C-67AD-11DF-AB5F-995D9DFF4B22","publication":{"authorities":[{"guid":"A83297F2-901A-11DF-A622-0C319DFF4B22","descr":"NGA Center/CCSSO","acronym":"CC"}],"regions":[{"code":"US","type":"country","descr":"United States of America","guid":"91273AE8-F1B9-11E5-862E-0938DC287387"},{"code":"CC","descr":"CCSS","guid":"A83297F2-901A-11DF-A622-0C319DFF4B22","type":"other"}],"descr":"Common Core State Standards","guid":"964E0FEE-AD71-11DE-9BF2-C9169DFF4B22","acronym":""}},"section":{"seq":920,"guid":"5E1166C2-7377-11DF-A1E8-223D9DFF4B22","descr":"Grade 5"},"seq":2,"disciplines":{"subjects":[{"descr":"Language Arts","guid":"F1FAC302-3B53-11E0-B042-495E9DFF4B22","code":"LANG"}],"strands":[{"guid":"81C38420-046C-11E0-9AE1-661C9DFF4B22","descr":"Reading"}]},"label":"","statement":{"addendums":[],"descr":"Literature"},"guid":"7F721838-7440-11DF-93FA-01FD9CFF4B22","utilizations":[],"number":{"enhanced":"CCSS.ELA-Literacy.RL.5","raw":"RL"},"education_levels":{"grades":[{"seq":70,"code":"5","descr":"5th Grade","guid":"F1FA3C84-3B53-11E0-B042-495E9DFF4B22"}]}},"type":"standards","relationships":{"parent":{"data":{"type":"standards","id":"286920E2-74F7-11DF-80DD-6B359DFF4B22"}}}},{"id":"27E73F1E-74F7-11DF-80DD-6B359DFF4B22","attributes":{"number":{"enhanced":"","raw":""},"utilizations":[],"guid":"27E73F1E-74F7-11DF-80DD-6B359DFF4B22","education_levels":{"grades":[{"guid":"F1FA3C84-3B53-11E0-B042-495E9DFF4B22","descr":"5th Grade","code":"5","seq":70}]},"status":"active","level":3,"label":"","statement":{"descr":"Key Ideas and Details","addendums":[]},"disciplines":{"subjects":[{"code":"LANG","descr":"Language Arts","guid":"F1FAC302-3B53-11E0-B042-495E9DFF4B22"}],"strands":[{"guid":"81C38420-046C-11E0-9AE1-661C9DFF4B22","descr":"Reading"}]},"seq":3,"section":{"descr":"Grade 5","guid":"5E1166C2-7377-11DF-A1E8-223D9DFF4B22","seq":920},"document":{"publication":{"guid":"964E0FEE-AD71-11DE-9BF2-C9169DFF4B22","descr":"Common Core State Standards","acronym":"","authorities":[{"acronym":"CC","descr":"NGA Center/CCSSO","guid":"A83297F2-901A-11DF-A622-0C319DFF4B22"}],"regions":[{"code":"US","descr":"United States of America","guid":"91273AE8-F1B9-11E5-862E-0938DC287387","type":"country"},{"code":"CC","guid":"A83297F2-901A-11DF-A622-0C319DFF4B22","descr":"CC ...
